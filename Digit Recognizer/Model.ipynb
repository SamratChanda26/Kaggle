# %%
# Disable warning
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
FAST_RUN = False
batch_size = 32
epochs = 100
if FAST_RUN:
    epochs = 1

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
print(train_data.columns)
# Out:
# Index(['label', 'pixel0', 'pixel1', 'pixel2', 'pixel3', 'pixel4', 'pixel5',
#        'pixel6', 'pixel7', 'pixel8',
#        ...
#        'pixel774', 'pixel775', 'pixel776', 'pixel777', 'pixel778', 'pixel779',
#        'pixel780', 'pixel781', 'pixel782', 'pixel783'],
#       dtype='object', length=785)

# %% [markdown]
# Show Image This is how 784 pixels of each row form to be images

# %%
def show_image(train_image, label, index):
    image_shaped = train_image.values.reshape(28, 28)
    plt.subplot(3, 6, index+1)
    plt.imshow(image_shaped, cmap = plt.cm.gray)
    plt.title(label)

plt.figure(figsize = (18, 8))
sample_image = train_data.sample(18).reset_index(drop = True)
for index, row in sample_image.iterrows():
    label = row['label']
    image_pixels = row.drop('label')
    show_image(image_pixels, label, index)
plt.tight_layout()

# %% [markdown]
# Split data for train and test

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

x = train_data.drop(columns = ['label']).values.reshape(train_data.shape[0], 28, 28, 1)
y = to_categorical(train_data['label'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)

# %% [markdown]
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range = 10,
    rescale = 1./255,
    shear_range = 0.1,
    zoom_range = 0.1,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)
train_datagen.fit(x_train)
train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size = batch_size
)

validation_datagen = ImageDataGenerator(rescale = 1./255)
train_datagen.fit(x_test)
validation_generator = validation_datagen.flow(
    x_test,
    y_test
)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Build CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

model = Sequential()
model.add(Conv2D(64, kernel_size = 3, activation = 'relu', input_shape = (28, 28, 1)))
model.add(Conv2D(32, kernel_size = 3, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(10, activation = 'softmax'))
# Out:
# 2023-11-19 10:46:58.263832: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:12.934142: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:12.934868: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:15.194919: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:15.218463: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:15.219053: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:15.219418: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:44.872825: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-19 10:47:44.873751: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:968] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience = 10, verbose = 1),
    ReduceLROnPlateau(factor = 0.1, patience = 3, min_lr = 0.00001, verbose = 1),
    ModelCheckpoint('model.h5', verbose = 1, save_best_only = True, save_weights_only = True)    
]

# %% [markdown]
# Fit Model

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch = len(x_train) // batch_size,
    validation_data = validation_generator,
    validation_steps = len(x_test) // batch_size,
    epochs = epochs,
    callbacks = callbacks
)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_5221/3651240944.py:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.3948 - accuracy: 0.8772
# Epoch 00001: val_loss improved from inf to 0.09195, saving model to model.h5
# 1181/1181 [==============================] - 91s 77ms/step - loss: 0.3948 - accuracy: 0.8772 - val_loss: 0.0920 - val_accuracy: 0.9726
# Epoch 2/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.1684 - accuracy: 0.9500
# Epoch 00002: val_loss improved from 0.09195 to 0.06504, saving model to model.h5
# 1181/1181 [==============================] - 16s 14ms/step - loss: 0.1685 - accuracy: 0.9499 - val_loss: 0.0650 - val_accuracy: 0.9809
# Epoch 3/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.1358 - accuracy: 0.9604
# Epoch 00003: val_loss improved from 0.06504 to 0.05762, saving model to model.h5
# 1181/1181 [==============================] - 16s 13ms/step - loss: 0.1357 - accuracy: 0.9605 - val_loss: 0.0576 - val_accuracy: 0.9819
# Epoch 4/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9681
# Epoch 00004: val_loss improved from 0.05762 to 0.04691, saving model to model.h5
# 1181/1181 [==============================] - 16s 14ms/step - loss: 0.1118 - accuracy: 0.9680 - val_loss: 0.0469 - val_accuracy: 0.9845
# Epoch 5/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9694
# Epoch 00005: val_loss improved from 0.04691 to 0.04294, saving model to model.h5
# 1181/1181 [==============================] - 16s 13ms/step - loss: 0.1041 - accuracy: 0.9694 - val_loss: 0.0429 - val_accuracy: 0.9859
# Epoch 6/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0935 - accuracy: 0.9720
# Epoch 00006: val_loss did not improve from 0.04294
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0937 - accuracy: 0.9720 - val_loss: 0.0530 - val_accuracy: 0.9843
# Epoch 7/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9733
# Epoch 00007: val_loss improved from 0.04294 to 0.03924, saving model to model.h5
# 1181/1181 [==============================] - 19s 16ms/step - loss: 0.0925 - accuracy: 0.9733 - val_loss: 0.0392 - val_accuracy: 0.9874
# Epoch 8/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0898 - accuracy: 0.9734
# Epoch 00008: val_loss improved from 0.03924 to 0.03714, saving model to model.h5
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0898 - accuracy: 0.9734 - val_loss: 0.0371 - val_accuracy: 0.9878
# Epoch 9/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0892 - accuracy: 0.9732
# Epoch 00009: val_loss did not improve from 0.03714
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0891 - accuracy: 0.9733 - val_loss: 0.0399 - val_accuracy: 0.9878
# Epoch 10/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0842 - accuracy: 0.9754
# Epoch 00010: val_loss did not improve from 0.03714
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0841 - accuracy: 0.9755 - val_loss: 0.0404 - val_accuracy: 0.9859
# Epoch 11/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9760
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00011: val_loss did not improve from 0.03714
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0824 - accuracy: 0.9760 - val_loss: 0.0441 - val_accuracy: 0.9854
# Epoch 12/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.0701 - accuracy: 0.9792
# Epoch 00012: val_loss improved from 0.03714 to 0.03541, saving model to model.h5
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0701 - accuracy: 0.9792 - val_loss: 0.0354 - val_accuracy: 0.9888
# Epoch 13/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9804
# Epoch 00013: val_loss did not improve from 0.03541
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0662 - accuracy: 0.9804 - val_loss: 0.0356 - val_accuracy: 0.9895
# Epoch 14/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9810
# Epoch 00014: val_loss did not improve from 0.03541
# 1181/1181 [==============================] - 16s 14ms/step - loss: 0.0659 - accuracy: 0.9810 - val_loss: 0.0382 - val_accuracy: 0.9883
# Epoch 15/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0683 - accuracy: 0.9807
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00015: val_loss did not improve from 0.03541
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0684 - accuracy: 0.9806 - val_loss: 0.0355 - val_accuracy: 0.9885
# Epoch 16/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0685 - accuracy: 0.9801
# Epoch 00016: val_loss improved from 0.03541 to 0.03503, saving model to model.h5
# 1181/1181 [==============================] - 17s 15ms/step - loss: 0.0684 - accuracy: 0.9801 - val_loss: 0.0350 - val_accuracy: 0.9883
# Epoch 17/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9817
# Epoch 00017: val_loss improved from 0.03503 to 0.03454, saving model to model.h5
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0635 - accuracy: 0.9817 - val_loss: 0.0345 - val_accuracy: 0.9888
# Epoch 18/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.0673 - accuracy: 0.9805
# Epoch 00018: val_loss did not improve from 0.03454
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0674 - accuracy: 0.9805 - val_loss: 0.0346 - val_accuracy: 0.9885
# Epoch 19/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9815
# Epoch 00019: val_loss did not improve from 0.03454
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0628 - accuracy: 0.9815 - val_loss: 0.0348 - val_accuracy: 0.9888
# Epoch 20/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9806
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00020: val_loss did not improve from 0.03454
# 1181/1181 [==============================] - 15s 13ms/step - loss: 0.0653 - accuracy: 0.9806 - val_loss: 0.0347 - val_accuracy: 0.9888
# Epoch 21/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9805
# Epoch 00021: val_loss improved from 0.03454 to 0.03448, saving model to model.h5
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0670 - accuracy: 0.9805 - val_loss: 0.0345 - val_accuracy: 0.9888
# Epoch 22/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9805
# Epoch 00022: val_loss improved from 0.03448 to 0.03435, saving model to model.h5
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0655 - accuracy: 0.9804 - val_loss: 0.0344 - val_accuracy: 0.9885
# Epoch 23/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9810
# Epoch 00023: val_loss did not improve from 0.03435
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0636 - accuracy: 0.9810 - val_loss: 0.0348 - val_accuracy: 0.9888
# Epoch 24/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9818
# Epoch 00024: val_loss did not improve from 0.03435
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0621 - accuracy: 0.9818 - val_loss: 0.0348 - val_accuracy: 0.9885
# Epoch 25/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9799
# Epoch 00025: val_loss did not improve from 0.03435
# 1181/1181 [==============================] - 22s 19ms/step - loss: 0.0672 - accuracy: 0.9799 - val_loss: 0.0347 - val_accuracy: 0.9883
# Epoch 26/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9814
# Epoch 00026: val_loss improved from 0.03435 to 0.03408, saving model to model.h5
# 1181/1181 [==============================] - 25s 22ms/step - loss: 0.0636 - accuracy: 0.9814 - val_loss: 0.0341 - val_accuracy: 0.9888
# Epoch 27/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9807
# Epoch 00027: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0640 - accuracy: 0.9807 - val_loss: 0.0348 - val_accuracy: 0.9883
# Epoch 28/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.0655 - accuracy: 0.9800
# Epoch 00028: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 17s 14ms/step - loss: 0.0654 - accuracy: 0.9801 - val_loss: 0.0348 - val_accuracy: 0.9878
# Epoch 29/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0623 - accuracy: 0.9810
# Epoch 00029: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 19s 16ms/step - loss: 0.0622 - accuracy: 0.9811 - val_loss: 0.0345 - val_accuracy: 0.9885
# Epoch 30/100
# 1179/1181 [============================>.] - ETA: 0s - loss: 0.0661 - accuracy: 0.9803
# Epoch 00030: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 18s 16ms/step - loss: 0.0660 - accuracy: 0.9804 - val_loss: 0.0348 - val_accuracy: 0.9883
# Epoch 31/100
# 1180/1181 [============================>.] - ETA: 0s - loss: 0.0653 - accuracy: 0.9813
# Epoch 00031: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 17s 15ms/step - loss: 0.0652 - accuracy: 0.9814 - val_loss: 0.0351 - val_accuracy: 0.9881
# Epoch 32/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9816
# Epoch 00032: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0645 - accuracy: 0.9816 - val_loss: 0.0354 - val_accuracy: 0.9885
# Epoch 33/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9806
# Epoch 00033: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0648 - accuracy: 0.9806 - val_loss: 0.0353 - val_accuracy: 0.9883
# Epoch 34/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9800
# Epoch 00034: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0697 - accuracy: 0.9801 - val_loss: 0.0350 - val_accuracy: 0.9883
# Epoch 35/100
# 1178/1181 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9805
# Epoch 00035: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 17s 15ms/step - loss: 0.0631 - accuracy: 0.9805 - val_loss: 0.0353 - val_accuracy: 0.9888
# Epoch 36/100
# 1181/1181 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9810
# Epoch 00036: val_loss did not improve from 0.03408
# 1181/1181 [==============================] - 18s 15ms/step - loss: 0.0657 - accuracy: 0.9810 - val_loss: 0.0351 - val_accuracy: 0.9881
# Epoch 00036: early stopping

# %% [markdown]
# Evaluate Model

# %%
x_test_recaled = (x_test.astype("float32") / 255)
scores = model.evaluate(x_test_recaled, y_test, verbose = 0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("%s: %.2f%%" % (model.metrics_names[0], scores[0]*100))
# Out:
# accuracy: 98.81%
# loss: 3.50%

# %% [markdown]
# Prediction

# %%
test_digit_data = test_data.values.reshape(test_data.shape[0], 28, 28, 1).astype("float32") / 225
predictions = model.predict(test_digit_data)
results = np.argmax(predictions, axis = 1)

# %% [markdown]
# Set how is our prediction

# %%
plt.figure(figsize = (18, 8))
sample_test = test_data.head(18)
for index, image_pixels in sample_test.iterrows():
    label = results[index]
    show_image(image_pixels, label, index)
plt.tight_layout()

# %% [markdown]
# Create submission file

# %%
submissions = pd.read_csv("sample_submission.csv")
submissions['Label'] = results
submissions.to_csv('submission.csv', index = False)
